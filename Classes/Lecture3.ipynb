# %%
x=7
y=2
print(x+y)
# Out:
# 9

# %%
x="welcome.to,vedam,for,learning.machine.learning "
x= x.replace("," , ".")
print(x)
# Out:
# welcome.to.vedam.for.learning.machine.learning

# %%
x = "charlie-bravo-alpha"
x = x.replace("charlie-bravo-alpha" , "ALPHA BRAVO CHARLIE")
print(x)
# Out:
# ALPHA BRAVO CHARLIE

# %%
x = "charlie-bravo-alpha"
y = x.split("_")
y =y[::-1]
y = [i.upper () for i in y]

# %%
x = [1,5,7]
y = x
print(id(x) == id(y))
# Out:
# True

# %%
x = " rahul KUMAR Sharma "
x=x.strip().title()
if all(i.isalpha() or i.isspace()for i in x):
    print(x)
else:
    print("invalid name")
# Out:
# Rahul Kumar Sharma

# %%
marks = input("Enter marks: ")

numbers = [int(x.strip()) for x in marks.split(",")]

total = sum(numbers)
average = total / len(numbers)

print("List:", numbers)
print("Total =", total)
print("Average =", average)
# Out:
# List: [45, 88, 72, 91, 60]
# Total = 356
# Average = 71.2

# %%
d = {1:1,2:4,3:9,4:16,}
