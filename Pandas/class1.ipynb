# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
import numpy as np

# %%
import pandas as pd

restaurant_data = {
    "table no": [1, 2, 3, 4, 5],
    "bill amount": [100, 200, 300, 400, 500],
    "waiter name": ["John", "Jane", "Jim", "Jill", "Jack"]
}
df = pd.DataFrame(restaurant_data)
print(df["bill amount"])
print(type(df["bill amount"]))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: bill amount, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
total_bill = [4700, 5600, 4300, 3900, 4800]
s = pd.Series(total_bill,index= ['monday', 'tuesday', 'wednesday', 'thursday', 'friday'])
print(s)
print(type(s))
# Out:
# monday       4700
# tuesday      5600
# wednesday    4300
# thursday     3900
# friday       4800
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(df)
print(type(df)x =df['daydhliweecbkuewbvlwbj fh kfbh ka kadebcecvj,h v ,v acdbjsvbsdhdns sd dS nds. h sd ,bsd,s jcjjjjjjdbqjdkxnchchkcbwlbclvysnnccjcjcjcjxx.kxxxjjxjxjxjxjjz'])
# Out:
#    table no  bill amount waiter name
# 0         1          100        John
# 1         2          200        Jane
# 2         3          300         Jim
# 3         4          400        Jill
# 4         5          500        Jack
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./tip.csv")

# %%
x = df['day']
print(x.shape)
y = df[['day']]
print(y.shape)
# Out:
# (244,)
# (244, 1)

# %%
pd.read_csv("Titanic-Dataset.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
