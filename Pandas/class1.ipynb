# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
import numpy as np

# %%
import pandas as pd

restaurant_data = {
    "table no": [1, 2, 3, 4, 5],
    "bill amount": [100, 200, 300, 400, 500],
    "waiter name": ["John", "Jane", "Jim", "Jill", "Jack"]
}
df = pd.DataFrame(restaurant_data)
print(df["bill amount"])
print(type(df["bill amount"]))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: bill amount, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
total_bill = [4700, 5600, 4300, 3900, 4800]
s = pd.Series(total_bill,index= ['monday', 'tuesday', 'wednesday', 'thursday', 'friday'])
print(s)
print(type(s))
# Out:
# monday       4700
# tuesday      5600
# wednesday    4300
# thursday     3900
# friday       4800
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
print(df)
print(type(df))
# Out:
#    table no  bill amount waiter name
# 0         1          100        John
# 1         2          200        Jane
# 2         3          300         Jim
# 3         4          400        Jill
# 4         5          500        Jack
# <class 'pandas.core.frame.DataFrame'>
