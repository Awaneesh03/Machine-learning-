# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/Titanic-Dataset.csv")
p = pd.read_csv("../data/Planets.csv")
tip = pd.read_csv("../data/tip.csv")

# %%
print(df.shape, p.shape)
# Out:
# (891, 12) (1035, 6)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[df.groupby('Pclass')['Age'].idxmax(),['Pclass','Name','Fare','Age']]
# Out:
#      Pclass                                  Name    Fare   Age
# 630       1  Barkworth, Mr. Algernon Henry Wilson  30.000  80.0
# 672       2           Mitchell, Mr. Henry Michael  10.500  70.0
# 851       3                   Svensson, Mr. Johan   7.775  74.0

# %%
tip.groupby("day").size()
# Out:
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# dtype: int64

# %%
tip.groupby("day")['tip'].mean().round(2)
# Out:
# day
# Fri     2.73
# Sat     2.99
# Sun     3.26
# Thur    2.77
# Name: tip, dtype: float64
